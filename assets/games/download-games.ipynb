# %%
swf_files = {'homerun_20201126': 'homerun.swf', 'stick-rpg-complete': 'Stick-RPG-Complete.swf', 'cannibals-missioneries': 'Cannibals_&_Missioneries.swf', 'swords-and-sandals-2': 'Swords and Sandals 2 (v 2.1.0).swf', 'bloxors': 'bloxors.swf', 'candy-bar-adventure-1': 'CandyBarAdventure (1).swf', 'SuperMarioCrossoverOffline': 'super_mario_bros_crossover.swf', 'mutilate-a-doll-2_202011': '164481_mutilate-a-doll-2_v4.swf', 'flash_picosschool': 'flash_picosschool.swf', 'bubble-shooter_swf': 'bubble-shooter.swf', 'bfdi_swf': 'ag-bfdi.swf', 'robotunicornattack_flash': 'robotunicornattack_flash.swf', 'a-koopas-revenge-2': "a koopa's revenge 2.swf", 'big-time-butter-baron': 'Big_Time_Butter_Baron.swf', 'noshootpuppy_flash': 'dont-shoot-the-puppy.swf', 'owata': 'owata.swf', 'super-mario-flash-2': 'super-mario-flash-2.swf', 'madness-project-nexus-classic': 'Madness Project Nexus Classic.swf', 'supersmashflash_swf': 'SuperSmash.swf', 'etp_20200826': '533001_PrisonNG.swf', 'flash_625-sandwich-stacker': '625-sandwich-stacker.swf', 'tiq2_swf': 'theimpossiblequiz2.swf', 'sports_heads_football_championship_flash': 'sports_heads_football_championship.swf', 'resort_empire_': 'resort-empire.swf', 'qwop_flash': 'qwop.swf', 'red-ball-2-the-king': 'redball2_theking.swf', 'penalty_fever': 'penalty_fever.swf', 'anime_summer_girl_dressup': 'LD22_enhanced.swf', 'bejeweled-ste': 'BejeweledSte.swf', 'atm-m3-simulator': 'metro_web.swf', 'princess_bonnie_dressup': 'princess_bonnie_dressup.swf', 'chibi-maker4': 'chibi-maker4.swf', 'polly_pocket_girl_photographer': '8253173674.swf', 'princess_hairstyle': 'princess_hairstyle.swf', 'earn_to-die': '74774.swf', 'freeway-fury-2': 'FF2.swf'}
# Out:
# Running cells with 'Python 3.9.13' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/Omita/AppData/Local/Programs/Python/Python39/python.exe -m pip install ipykernel -U --user --force-reinstall'
